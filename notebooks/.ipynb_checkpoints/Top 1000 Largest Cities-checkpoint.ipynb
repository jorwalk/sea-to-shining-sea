# %%
import json
import pathlib
import itertools

from geopy import distance

# %%
file = '1000-largest-us-cities-by-population-with-geographic-coordinates.json'
cities = pathlib.Path.cwd().joinpath(file)
with open(cities) as json_file:
    largest_cities = json.load(json_file)

# %%
import pprint
pprint.pprint(largest_cities)
# Out:
# [{'datasetid': '1000-largest-us-cities-by-population-with-geographic-coordinates',
#   'fields': {'city': 'South San Francisco',
#              'coordinates': [37.654656, -122.4077498],
#              'growth_from_2000_to_2013': 9.1,
#              'population': 66174,
#              'rank': 522,
#              'state': 'California'},
#   'geometry': {'coordinates': [-122.4077498, 37.654656], 'type': 'Point'},
#   'record_timestamp': '2017-06-01T09:40:33-05:00',
#   'recordid': '5ce7a9aa87f003a5af134718daffe9154c06ab72'},
#  {'datasetid': '1000-largest-us-cities-by-population-with-geographic-coordinates',
#   'fields': {'city': 'Aliso Viejo',
#              'coordinates': [33.5676842, -117.7256083],
#              'growth_from_2000_to_2013': 25.4,
#              'population': 50175,
#              'rank': 741,
#              'state': 'California'},
#   'geometry': {'coordinates': [-117.7256083, 33.5676842], 'type': 'Point'},
#   'record_timestamp': '2017-06-01T09:40:33-05:00',
# ...

# %%
matrix = []
for i in range(0, len(largest_cities)):
    # the initial capital where the distance will be computed from
    a_lat = largest_cities[i].get('fields')['coordinates'][0]
    a_lon = largest_cities[i].get('fields')['coordinates'][1]

    a = (a_lat, a_lon)

    dist = []
    # iterate over the rest of the capitals]
    for city in largest_cities:
        b_lat = city.get('fields')['coordinates'][0]
        b_lon = city.get('fields')['coordinates'][1]

        b = (b_lat, b_lon)

        # calculate the distance between the two
        miles = round(distance.distance(a, b).miles)
        dist.append(miles)

    matrix.append(dist)

# %%
print(matrix)

# %%
class Data:
    def __init__(self):
        self.matrix = []
        states = pathlib.Path.cwd().joinpath('src','states.json')
        with open(states) as json_file:
            self.capitals = json.load(json_file)

    def distance(self):
        for i in range(0, 50):
            # the initial capital where the distance will be computed from
            a_lat = self.capitals[i].get('lat')
            a_lon = self.capitals[i].get('long')

            a = (a_lat, a_lon)

            dist = []
            # iterate over the rest of the capitals]
            for capital in self.capitals:
                b_lat = capital.get('lat')
                b_lon = capital.get('long')

                b = (b_lat, b_lon)

                # calculate the distance between the two
                miles = round(distance.distance(a, b).miles)
                dist.append(miles)

            self.matrix.append(dist)

    def capital_name(self, idx):
        return self.capitals[idx].get('capital')

    def pairwise(self, iterable):
        a, b = itertools.tee(iterable)
        next(b, None)
        return zip(a, b)

    def flight_path(self, sequence):
        flight_path = []
        for x in list(self.pairwise(sequence)):
            from_capital = self.capitals[x[0]]
            to_capital = self.capitals[x[1]]

            from_path = [
                float(from_capital.get('lat')),
                float(from_capital.get('long'))]

            to_path = [
                float(to_capital.get('lat')),
                float(to_capital.get('long'))]

            flight_path.append([from_path, to_path])

        return flight_path
